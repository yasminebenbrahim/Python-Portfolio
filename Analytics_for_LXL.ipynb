# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminebenbrahim/Python-SQL-Portfolio/blob/master/Analytics_for_LXL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #How many Jobs where won by Bidder(s), by Type, By Tag? Include the # of jobs won, average bid cost, and average returns score
#
#  group by Bidder (to look at success rate on individuals)
#
#  group by date to look at successful seasons ... how to convert string to date and use MONTH() function

# %%
import pandas as pd
from pandas.io import gbq

# %%
bidders = 'SELECT * FROM `lxl-and-produzen.LXL.Qty_JobsWon_by_Bidder` LIMIT 1000'
bidders = gbq.read_gbq(bidders, project_id='lxl-and-produzen')
bidders
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=l0LpeoSguxOrlkPaHIDtjyCS7rUbbG&prompt=consent&access_type=offline
# Enter the authorization code: 4/4QFNbpZLZlHJNI4inLEW4mgeeUAa1wczuRa0M9CCVCTBORIi9OwodQs
#     JobsWon  ...                                          Bidder_s_
# 0        23  ...  https://www.notion.so/Victoria-b74b1d791d88478...
# 1         9  ...  https://www.notion.so/Robert-12e328671f624119a...
# 2         4  ...  https://www.notion.so/Victoria-b74b1d791d88478...
# 3         4  ...  https://www.notion.so/Ree-fdc279bf9ef14031a36c...
# 4         3  ...  https://www.notion.so/Cheri-9fa9fe8c8e8448f69f...
# 5         2  ...  https://www.notion.so/Victoria-b74b1d791d88478...
# ...

# %%
jobs_by_tags = 'SELECT * FROM `lxl-and-produzen.LXL.Qty_JobsWon_By_Tags` LIMIT 1000'
jobs_by_tags = gbq.read_gbq(jobs_by_tags, project_id='lxl-and-produzen')
jobs_by_tags
# Out:
#                                 Tags  JobsWon  AvgBidCost  AvgReturnsScore
# 0                               None       16     1533.44             1.27
# 1                             Pharma        6     3947.50             1.99
# 2                               Auto        4     2602.38             2.66
# 3                               Food        4     1676.25             2.71
# 4                         Healthcare        3     3019.00             2.10
# 5                              Celeb        3      701.93             2.20
# 6                        Web/On-Line        2     1147.50             0.91
# 7                             Sports        2      212.20             1.75
# 8                       Retail Goods        2     2859.50             1.20
# 9                                PSA        2      460.50             1.83
# 10                         Financial        2     2375.00             2.62
# ...

# %%
jobs_by_type = 'SELECT * FROM `lxl-and-produzen.LXL.Qty_JobsWon_By_Type` LIMIT 1000'
jobs_by_type = gbq.read_gbq(jobs_by_type, project_id='lxl-and-produzen')
jobs_by_type
# Out:
#                                 Type  JobsWon  AvgBidCost  AvgReturnsScore
# 0                         Commercial       34     2514.10             2.14
# 1                               None       14     1346.00             1.30
# 2                  Commercial, Large        3     2295.33             1.85
# 3                        Music Video        2      801.50             2.41
# 4                  Commercial, Small        1         NaN             1.75
# 5                  Long Form Content        1     1430.00             2.13
# 6          Live Action, Promo/Teaser        1      502.80             1.79
# 7                 Large, Music Video        1     1113.00             2.53
# 8      Commercial, Long Form Content        1     1430.00             2.61
# 9                   Commercial, Post        1      750.00             2.97
# 10                     Short Content        1      600.00             2.61
# ...
